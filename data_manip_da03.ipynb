# %%
import pandas as pd

# %%
hless = pd.read_csv("C:\\Users\DELL\homelessnes.csv")

# %%
#Checking the data loaded into dataframe
hless.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
#identifying number of rows and columns
hless.shape
# Out:
# (51, 5)

# %%
#complete information of table
hless.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     int64
#  3   family_members  51 non-null     int64
#  4   state_pop       51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#statistical information of the table - works on only numerical fields
hless.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
#checking out the values in the dataframe
hless.values
# Out:
# array([['East South Central', 'Alabama', 2570, 864, 4887681],
#        ['Pacific', 'Alaska', 1434, 582, 735139],
#        ['Mountain', 'Arizona', 7259, 2606, 7158024],
#        ['West South Central', 'Arkansas', 2280, 432, 3009733],
#        ['Pacific', 'California', 109008, 20964, 39461588],
#        ['Mountain', 'Colorado', 7607, 3250, 5691287],
#        ['New England', 'Connecticut', 2280, 1696, 3571520],
#        ['South Atlantic', 'Delaware', 708, 374, 965479],
#        ['South Atlantic', 'District of Columbia', 3770, 3134, 701547],
#        ['South Atlantic', 'Florida', 21443, 9587, 21244317],
#        ['South Atlantic', 'Georgia', 6943, 2556, 10511131],
#        ['Pacific', 'Hawaii', 4131, 2399, 1420593],
#        ['Mountain', 'Idaho', 1297, 715, 1750536],
#        ['East North Central', 'Illinois', 6752, 3891, 12723071],
#        ['East North Central', 'Indiana', 3776, 1482, 6695497],
#        ['West North Central', 'Iowa', 1711, 1038, 3148618],
# ...

# %%
hless.head(10)
# Out:
#                region                 state  individuals  family_members  \
# 0  East South Central               Alabama         2570             864
# 1             Pacific                Alaska         1434             582
# 2            Mountain               Arizona         7259            2606
# 3  West South Central              Arkansas         2280             432
# 4             Pacific            California       109008           20964
# 5            Mountain              Colorado         7607            3250
# 6         New England           Connecticut         2280            1696
# 7      South Atlantic              Delaware          708             374
# 8      South Atlantic  District of Columbia         3770            3134
# 9      South Atlantic               Florida        21443            9587
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588
# 5    5691287
# 6    3571520
# 7     965479
# 8     701547
# 9   21244317

# %%
hless.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
#sorting values based on region
hless.sort_values("region")
# Out:
#                 region                 state  individuals  family_members  \
# 35  East North Central                  Ohio         6929            3320
# 49  East North Central             Wisconsin         2740            2167
# 22  East North Central              Michigan         5209            3142
# 13  East North Central              Illinois         6752            3891
# 14  East North Central               Indiana         3776            1482
# 0   East South Central               Alabama         2570             864
# 42  East South Central             Tennessee         6139            1744
# 24  East South Central           Mississippi         1024             328
# 17  East South Central              Kentucky         2735             953
# 38        Mid-Atlantic          Pennsylvania         8163            5349
# 32        Mid-Atlantic              New York        39827           52070
# 30        Mid-Atlantic            New Jersey         6048            3350
# ...

# %%
#sorting based on multiple fields with assending and desceding order
hless.sort_values(["region","state"], ascending=[False, True])
# Out:
#                 region                 state  individuals  family_members  \
# 3   West South Central              Arkansas         2280             432
# 18  West South Central             Louisiana         2540             519
# 36  West South Central              Oklahoma         2823            1048
# 43  West South Central                 Texas        19199            6111
# 15  West North Central                  Iowa         1711            1038
# 16  West North Central                Kansas         1443             773
# 23  West North Central             Minnesota         3993            3250
# 25  West North Central              Missouri         3776            2107
# 27  West North Central              Nebraska         1745             676
# 34  West North Central          North Dakota          467              75
# 41  West North Central          South Dakota          836             323
# 7       South Atlantic              Delaware          708             374
# ...

# %%
#retrieving desired field from df
hless["region"]
# Out:
# 0     East South Central
# 1                Pacific
# 2               Mountain
# 3     West South Central
# 4                Pacific
# 5               Mountain
# 6            New England
# 7         South Atlantic
# 8         South Atlantic
# 9         South Atlantic
# 10        South Atlantic
# 11               Pacific
# 12              Mountain
# 13    East North Central
# 14    East North Central
# 15    West North Central
# 16    West North Central
# 17    East South Central
# 18    West South Central
# 19           New England
# 20        South Atlantic
# 21           New England
# 22    East North Central
# 23    West North Central
# 24    East South Central
# 25    West North Central
# 26              Mountain
# 27    West North Central
# 28              Mountain
# 29           New England
# 30          Mid-Atlantic
# 31              Mountain
# 32          Mid-Atlantic
# 33        South Atlantic
# 34    West North Central
# 35    East North Central
# 36    West South Central
# ...

# %%
#subsetting the df
hless_new = hless[["region", "individuals", "family_members"]]

# %%
hless_new
# Out:
#                 region  individuals  family_members
# 0   East South Central         2570             864
# 1              Pacific         1434             582
# 2             Mountain         7259            2606
# 3   West South Central         2280             432
# 4              Pacific       109008           20964
# 5             Mountain         7607            3250
# 6          New England         2280            1696
# 7       South Atlantic          708             374
# 8       South Atlantic         3770            3134
# 9       South Atlantic        21443            9587
# 10      South Atlantic         6943            2556
# 11             Pacific         4131            2399
# 12            Mountain         1297             715
# 13  East North Central         6752            3891
# 14  East North Central         3776            1482
# 15  West North Central         1711            1038
# 16  West North Central         1443             773
# ...

# %%
#subsetting it based on a condition applied on the field
hless_new["family_members"] > 5000
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# Name: family_members, dtype: bool

# %%
hless_new[hless_new["family_members"] > 5000]
# Out:
#                 region  individuals  family_members
# 4              Pacific       109008           20964
# 9       South Atlantic        21443            9587
# 21         New England         6811           13257
# 32        Mid-Atlantic        39827           52070
# 38        Mid-Atlantic         8163            5349
# 43  West South Central        19199            6111
# 47             Pacific        16424            5880

# %%
hless_find = hless["region"].isin(["Pacific"])

# %%
#Filtering the records based on a specific condition
hless[hless_find]
# Out:
#      region       state  individuals  family_members  state_pop
# 1   Pacific      Alaska         1434             582     735139
# 4   Pacific  California       109008           20964   39461588
# 11  Pacific      Hawaii         4131            2399    1420593
# 37  Pacific      Oregon        11139            3337    4181886
# 47  Pacific  Washington        16424            5880    7523869

# %%
hless[hless["region"].isin(["Pacific"])]
# Out:
#      region       state  individuals  family_members  state_pop
# 1   Pacific      Alaska         1434             582     735139
# 4   Pacific  California       109008           20964   39461588
# 11  Pacific      Hawaii         4131            2399    1420593
# 37  Pacific      Oregon        11139            3337    4181886
# 47  Pacific  Washington        16424            5880    7523869

# %%
#creating a new column
hless["mynew_indv"] = hless["individuals"] / 2

# %%
hless
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
hless.describe()
# Out:
#          individuals  family_members     state_pop    mynew_indv
# count      51.000000       51.000000  5.100000e+01     51.000000
# mean     7225.784314     3504.882353  6.405637e+06   3612.892157
# std     15991.025083     7805.411811  7.327258e+06   7995.512542
# min       434.000000       75.000000  5.776010e+05    217.000000
# 25%      1446.500000      592.000000  1.777414e+06    723.250000
# 50%      3082.000000     1482.000000  4.461153e+06   1541.000000
# 75%      6781.500000     3196.000000  7.340946e+06   3390.750000
# max    109008.000000    52070.000000  3.946159e+07  54504.000000

# %%
#finding the minimum value of the field
hless["family_members"].min()
# Out:
# 75

# %%
 hless
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
#creating desired filed as index to the dataframe
new_hlessindx = hless.set_index("state")

# %%
new_hlessindx
# Out:
#                                   region  individuals  family_members  \
# state
# Alabama               East South Central         2570             864
# Alaska                           Pacific         1434             582
# Arizona                         Mountain         7259            2606
# Arkansas              West South Central         2280             432
# California                       Pacific       109008           20964
# Colorado                        Mountain         7607            3250
# Connecticut                  New England         2280            1696
# Delaware                  South Atlantic          708             374
# District of Columbia      South Atlantic         3770            3134
# Florida                   South Atlantic        21443            9587
# Georgia                   South Atlantic         6943            2556
# Hawaii                           Pacific         4131            2399
# ...

# %%
#creating multiple indexes
new_hlessindx = hless.set_index(["state","individuals"])

# %%
new_hlessindx
# Out:
#                                               region  family_members  \
# state                individuals
# Alabama              2570         East South Central             864
# Alaska               1434                    Pacific             582
# Arizona              7259                   Mountain            2606
# Arkansas             2280         West South Central             432
# California           109008                  Pacific           20964
# Colorado             7607                   Mountain            3250
# Connecticut          2280                New England            1696
# Delaware             708              South Atlantic             374
# District of Columbia 3770             South Atlantic            3134
# Florida              21443            South Atlantic            9587
# Georgia              6943             South Atlantic            2556
# Hawaii               4131                    Pacific            2399
# ...

# %%
#resetting the index values
new_hlessindx.reset_index()
# Out:
#                    state  individuals              region  family_members  \
# 0                Alabama         2570  East South Central             864
# 1                 Alaska         1434             Pacific             582
# 2                Arizona         7259            Mountain            2606
# 3               Arkansas         2280  West South Central             432
# 4             California       109008             Pacific           20964
# 5               Colorado         7607            Mountain            3250
# 6            Connecticut         2280         New England            1696
# 7               Delaware          708      South Atlantic             374
# 8   District of Columbia         3770      South Atlantic            3134
# 9                Florida        21443      South Atlantic            9587
# 10               Georgia         6943      South Atlantic            2556
# 11                Hawaii         4131             Pacific            2399
# ...

# %%
import matplotlib.pyplot as plt

# %%
hless["region"].hist()
# Out:
# <Axes: >

# %%
hless.plot(x="state", y="state_pop", kind="line")
# Out:
# <Axes: xlabel='state'>

# %%
#dropping fileds from the dataframe
fdrp = hless.drop("region", axis=1)

# %%
fdrp.head()
# Out:
#         state  individuals  family_members  state_pop  mynew_indv
# 0     Alabama         2570             864    4887681      1285.0
# 1      Alaska         1434             582     735139       717.0
# 2     Arizona         7259            2606    7158024      3629.5
# 3    Arkansas         2280             432    3009733      1140.0
# 4  California       109008           20964   39461588     54504.0

# %%
#dropping rows/records from the dataframe
rdrp = hless.drop([2,10,17], axis=0)

# %%
rdrp.head()
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588
# 5            Mountain    Colorado         7607            3250    5691287
#
#    mynew_indv
# 0      1285.0
# 1       717.0
# 3      1140.0
# 4     54504.0
# 5      3803.5
