# %% [markdown]
# # Data Analysis of Olist Store

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide1.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide2.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide3.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide4.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide5.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide6.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide7.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide8.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide9.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide10.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide11.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide12.jpg')

# %%
from IPython.display import Image
Image(filename='C:/Users/DELL/Olist slides/Slide13.jpg')
